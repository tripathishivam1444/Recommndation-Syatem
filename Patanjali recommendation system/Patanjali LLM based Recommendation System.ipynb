# %%
import pandas as pd
import missingno

# %%
df = pd.read_csv('all_product_details.csv')

# %%
df
# Out:
#             poduct_category                           Product Name  \
# 0                digestives              Patanjali Pachak Jaljeera
# 1                digestives             Patanjali Pachak Hing Goli
# 2                digestives  Patanjali Pachak Ajwain with Aloevera
# 3                digestives             Patanjali Pachak Hing Peda
# 4                digestives                   Pachak Shodhit Harad
# ..                      ...                                    ...
# 886  plant-growth-promoters                        Patanjali Umang
# 887  plant-growth-promoters                      Patanjali Gibrika
# 888  plant-growth-promoters                       Patanjali Sparsh
# 889  plant-growth-promoters                   Patanjali Fasal Tara
# 890  plant-growth-promoters                Patanjali Jaivik Kranti
#
#                                                   Link  \
# 0    https://www.patanjaliayurved.net/product/natur...
# ...

# %%
missingno.matrix(df)
# Out:
# <Axes: >
